# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n = np.arange(-10, 11, 1)
x = (n + 3)
x[n >= 0] = 3
x = x * (np.abs(n) <= 3)

fig = figure(figsize=(15, 4))
ax = fig.add_subplot(111)
ax.stem(n, x)
ax.set_xlim(n[0], n[-1])
ax.set_ylim(-0.5, 3.5)
ax.set_xticks(n)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)
plt.tight_layout()

fig.savefig("discsig.png", format="png", dpi=300)
fig.savefig("discsig.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n + 3)
x[n >= 0] = 3
x = x * (np.abs(n) <= 3)

fig = figure(figsize=(15, 4))
ax = fig.add_subplot(111)
ax.stem(n + 3, x)
ax.set_ylim(-0.5, 3.5)
ax.set_xticks(n)
ax.set_xlim(-10, 10)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)
plt.tight_layout()

fig.savefig("discsig-shift.png", format="png", dpi=300)
fig.savefig("discsig-shift.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n + 3)
x[n >= 0] = 3
x = x * (np.abs(n) <= 3)

fig = figure(figsize=(15, 4))
ax = fig.add_subplot(111)
ax.stem(n - 2, x)
ax.set_ylim(-0.5, 3.5)
ax.set_xticks(n)
ax.set_xlim(-10, 10)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)
plt.tight_layout()

fig.savefig("discsig-shift2.png", format="png", dpi=300)
fig.savefig("discsig-shift2.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n + 3)
x[n >= 0] = 3
x = x * (np.abs(n) <= 3)

fig = figure(figsize=(15, 4))
ax = fig.add_subplot(111)
ax.stem(-n, x)
ax.set_ylim(-0.5, 3.5)
ax.set_xticks(n)
ax.set_xlim(-10, 10)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)
plt.tight_layout()

fig.savefig("discsig-inv.png", format="png", dpi=300)
fig.savefig("discsig-inv.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n >= 0) * (n <= 10)
N = 4
y = np.array([np.sum(x[i-N+1:i+1]) if i >= 3
              else np.sum(x[:i])
              for i, _ in enumerate(n)]) * (1 / N)

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, y)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = (1/4) \cdot \sum_{k=0}^{3} x[n - k]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("memory.png", format="png", dpi=300)
fig.savefig("memory.eps", format="eps", dpi=300)
stem(n, y)
# Out:
# <StemContainer object of 3 artists>

# %%
n = np.arange(-20, 21, 1)
x = (n >= 0) * (n <= 10)
N = 2
y = np.array([np.sum(x[max(0, i-N+1):min(len(n), i+N+1)])
              for i, _ in enumerate(n)]) * (1 / (2 * N))

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, y)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = (1/4) \cdot \sum_{k=-2}^{1} x[n - k]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("non-causal.png", format="png", dpi=300)
fig.savefig("non-causal.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n >= 0) * (n <= 10)
N = 4
y = np.array([np.sum(x[i-N+1:i+1]) if i >= 3
              else np.sum(x[:i])
              for i, _ in enumerate(n)]) * (1 / N)

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, y)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = (1/4) \cdot \sum_{k=-2}^{1} x[n - k]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("timeinvar1.png", format="png", dpi=300)
fig.savefig("timeinvar1.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n >= 0) * (n <= 10)
N = 4
y = np.array([np.sum(x[i-N+1:i+1]) if i >= 3
              else np.sum(x[:i])
              for i, _ in enumerate(n)]) * (1 / N)

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n + 6, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n + 6, y)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = (1/4) \cdot \sum_{k=-2}^{1} x[n - k]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("timeinvar2.png", format="png", dpi=300)
fig.savefig("timeinvar2.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = (n >= 0) * (n <= 10)
N = 2
y = 0.75 * n * x

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, y)
ax.set_ylim(-0.5, 12)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = n \cdot x[n]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("timevar1.png", format="png", dpi=300)
fig.savefig("timevar1.eps", format="eps", dpi=300)

# %%
n = np.arange(-20, 21, 1)
x = ((n - 5) >= 0) * ((n - 5) <= 10)
N = 2
y = 0.75 * n * x

fig = figure(figsize=(15, 7))
ax = fig.add_subplot(211)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, x)
ax.set_ylim(-0.5, 1.5)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$x[n]$", fontsize=20)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

ax = fig.add_subplot(212)
ax.axvline(0, lw=1, color="0.5", linestyle="dashed")
ax.stem(n, y)
ax.set_ylim(-0.5, 12)
ax.set_xticks(n)
ax.set_xlim(-5, 20)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.set_xlabel("$n$", fontsize=20)
ax.set_ylabel("$y[n]$", fontsize=20)
ax.set_title("$y[n] = n \cdot x[n]$", fontsize=14)
ax.grid(color='0.85', linestyle='-', linewidth=0.5)

plt.tight_layout()

fig.savefig("timevar2.png", format="png", dpi=300)
fig.savefig("timevar2.eps", format="eps", dpi=300)
