# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
outdir = "output/ztransform/"

# %% [markdown]
# ## Different signals and their ROC

# %%
fig = figure(figsize=(12, 8))

ax = fig.add_subplot(3, 2, 1)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([0, 0, 0, 0, 0, 1, 0.5, 0.25, 0.125, 0, 0])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Causal, finite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_xaxis().set_ticklabels([])
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 2)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax = fig.add_subplot(3, 2, 3)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([0, 0, 0, 0, 0, 1, 0.5, 0.25, 0.125, 0, 0][::-1])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Anticausal, finite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 4)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax = fig.add_subplot(3, 2, 5)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([0, 0, 0.15, 0.3, 0.9, 1, 0.5, 0.25, 0.125, 0, 0][::-1])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Two-sided, finite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 6)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tight_layout(w_pad=10)

fig.savefig(f"{outdir}/ztrans-finite-dur.svg", format="svg", dpi=300);
fig.savefig(f"{outdir}/ztrans-finite-dur.png", format="png", dpi=300);

# %%
fig = figure(figsize=(12, 8))

ax = fig.add_subplot(3, 2, 1)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([0, 0, 0, 0, 0, 1, 0.5, 0.25, 0.125, 0.0625, 0.03125])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Causal, infinite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_xaxis().set_ticklabels([])
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 2)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax = fig.add_subplot(3, 2, 3)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([0, 0, 0, 0, 0, 1, 0.5, 0.25, 0.125, 0.0625, 0.03125][::-1])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Anticausal, infinite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 4)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax = fig.add_subplot(3, 2, 5)
ax.grid(color='0.8', linestyle='--', linewidth=0.5);
_n = np.arange(-5, 6)
ax.axvline(5, lw=0.5, color="k")
ax.stem([np.power(0.9, 5), np.power(0.9, 4), np.power(0.9, 3),
         np.power(0.9, 2), 0.9, 1, 0.5, 0.25, 0.125, 0, 0][::-1])
ax.set_ylim(-0.1, 1.5)
ax.set_title(r"Two-sided, infinite duration, $x[n]$", fontsize=18)
ax.set_xlabel(r"$n$", fontsize=16)
xticks(fontsize=16)
yticks(fontsize=16)
ax.get_yaxis().set_ticklabels([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

ax = fig.add_subplot(3, 2, 6)
ax.axhline(0, lw=1, color="k")
ax.axvline(0, lw=1, color="k")
ax.set_xlim([-3, 3])
ax.set_ylim([-3, 3])
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.tight_layout(w_pad=10)

fig.savefig(f"{outdir}/ztrans-infinite-dur.svg", format="svg", dpi=300);
fig.savefig(f"{outdir}/ztrans-infinite-dur.png", format="png", dpi=300);
